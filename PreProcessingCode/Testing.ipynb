# %%
import main

# %%
main.main()
# Out:
# (1795, 512, 256)
# (1795,)
# (599, 512, 256)
# (599,)
# Epoch 1/10
# 57/57 [==============================] - 169s 3s/step - loss: 167806864.0000 - sparse_categorical_accuracy: 0.7053
# Epoch 2/10
# 57/57 [==============================] - 162s 3s/step - loss: 14245925.0000 - sparse_categorical_accuracy: 0.7599
# Epoch 3/10
# 57/57 [==============================] - 161s 3s/step - loss: 8114774.0000 - sparse_categorical_accuracy: 0.7627
# Epoch 4/10
# 57/57 [==============================] - 161s 3s/step - loss: 885073600.0000 - sparse_categorical_accuracy: 0.8958
# Epoch 5/10
# 57/57 [==============================] - 167s 3s/step - loss: 0.4381 - sparse_categorical_accuracy: 0.9393
# Epoch 6/10
# 57/57 [==============================] - 164s 3s/step - loss: 0.5930 - sparse_categorical_accuracy: 0.9226
# Epoch 7/10
# 57/57 [==============================] - 171s 3s/step - loss: 0.4320 - sparse_categorical_accuracy: 0.9270
# Epoch 8/10
# ...
